# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("Advertising.csv",index_col=0)

# %%
data.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
#Data Processing

# %%
x = data["TV"]
y = data["sales"]
x1= data["radio"]
x2= data["newspaper"]

# %%
plt.scatter(x,y)
plt.xlabel("TV")
plt.ylabel("sales")
plt.title("sales vs TV Advertising")
# Out:
# Text(0.5, 1.0, 'sales vs TV Advertising')

# %%
plt.scatter(x1,y)
plt.xlabel("radio")
plt.ylabel("sales")
plt.title("sales vs radio Advertising")
# Out:
# Text(0.5, 1.0, 'sales vs radio Advertising')

# %%
plt.scatter(x2,y)
plt.xlabel("newspaper")
plt.ylabel("sales")
plt.title("sales vs newspaper Advertising")
# Out:
# Text(0.5, 1.0, 'sales vs newspaper Advertising')

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
data.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
plt.boxplot(data["newspaper"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2113282cc10>,
#   <matplotlib.lines.Line2D at 0x211328eb150>],
#  'caps': [<matplotlib.lines.Line2D at 0x211328ea290>,
#   <matplotlib.lines.Line2D at 0x21133981d10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21132c5e050>],
#  'medians': [<matplotlib.lines.Line2D at 0x211328e8850>],
#  'fliers': [<matplotlib.lines.Line2D at 0x211328e3cd0>],
#  'means': []}

# %%
#Linear Regresion
#Y = b0 + b1x1

# %%
x = data[["TV","radio","newspaper"]]
y = data[["sales"]]

# %%
import sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20)

# %%
print("shape of x-train",x_train.shape)
print("shape of x-test",x_test.shape)
print("shape of y-train",y_train.shape)
print("shape of y-test",y_test.shape)
# Out:
# shape of x-train (160, 3)
# shape of x-test (40, 3)
# shape of y-train (160, 1)
# shape of y-test (40, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
model= lm.fit(x_train,y_train)

# %%
print(lm.coef_)
# Out:
# [[0.04608225 0.18667514 0.00150066]]

# %%
print(lm.intercept_)
# Out:
# [2.89721921]

# %%
#y = b0 + b1x1 +b2x2 +b3x3

# %%
b0= 2.89721921
b1= 0.04608225
b2= 0.18667514
b3= 0.00150066

# %%
y = b0 + b1*230.1 +b2*37.8 +b3*69.2

# %%
y
# Out:
# 20.660910898999994

# %%
y_pred = lm.predict(x_test)

# %%
new_df = pd.DataFrame()
new_df = x_test
new_df["actual sales"]= y_test
new_df["predicted sales"]= y_pred
new_df
# Out:
#         TV  radio  newspaper  actual sales  predicted sales
# 147  240.1    7.3        8.7          13.2        15.337351
# 120   19.4   16.0       22.3           6.6         6.811482
# 82   239.8    4.1       36.9          12.3        14.768484
# 71   199.1   30.6       38.7          18.3        17.842529
# 51   199.8    3.1       34.6          11.4        12.735068
# 98   184.9   21.0       22.0          15.5        15.371019
# 196   38.2    3.7       13.8           7.6         5.368968
# 127    7.8   38.9       50.6           6.6        10.594257
# 151  280.7   13.9       37.0          16.1        18.482815
# 26   262.9    3.5       19.5          12.0        15.694868
# 16   195.4   47.7       52.9          22.4        20.885479
# 182  218.5    5.4       27.4          12.2        14.015354
# 168  206.8    5.2       19.4          12.2        13.426851
# 105  238.2   34.3        5.3          20.7        20.284921
# 54   182.6   46.2       58.7          21.2        20.024318
# 35    95.7    1.4        7.4           9.5         7.579740
# 143  220.5   33.2       37.9          20.1        19.312844
# 12   214.7   24.0        4.0          17.4        17.277284
# 197   94.2    4.9        8.1           9.7         8.165030
# 188  191.1   28.7       18.2          17.3        17.088425
# 23    13.2   15.9       49.6           5.6         6.548072
# 159   11.7   36.9       45.2           7.3        10.392524
# 8    120.2   19.6       11.6          13.2        12.112546
# 34   265.6   20.0        0.3          17.4        18.870617
# 142  193.7   35.4       75.6          19.2        18.545100
# 50    66.9   11.7       36.8           9.7         8.219445
# 193   17.2    4.1       31.6           5.9         4.502623
# 177  248.4   30.2       20.3          20.2        20.012102
# 99   289.7   42.3       51.2          25.4        24.220438
# 109   13.1    0.4       25.6           5.3         3.613983
# 156    4.1   11.6        5.7           3.2         5.260142
# 81    76.4   26.7       22.3          11.8        11.435594
# 157   93.9   43.5       50.5          15.3        15.420494
# 160  131.7   18.4       34.6          12.9        12.452996
# 150   44.7   25.8       20.6          10.1         9.804228
# 49   227.2   15.8       49.9          14.8        16.391456
# 1    230.1   37.8       69.2          22.1        20.660910
# 76    16.9   43.7       89.4           8.7        11.967871
# 128   80.2    0.0        9.2           8.8         6.606822
# 121  141.3   26.8       46.2          15.5        14.480865

# %%
from sklearn.metrics import r2_score,mean_squared_error
import numpy as np
r2=r2_score(y_test,y_pred)
print("R2 squared",r2)

rmse=np.sqrt(mean_squared_error(y_test,y_pred))
print ("RMSE:",rmse)
# Out:
# R2 squared 0.9020213030843864
# RMSE: 1.7088665997069323

# %%
new_df.to_csv("updated.csv")
